# %% [markdown]
# <a href="https://colab.research.google.com/github/yianchen903/my-project/blob/main/source_term.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
x, y, t = sp.symbols('x y t')


r = (x**2+y**2)**0.5




Hex2D = sp.sin(sp.pi*x)*sp.sin(sp.pi*y)
#-------------------
u = Hex2D

u_t = u.diff(t)
u_x = u.diff(x)
u_y = u.diff(y)

# au = 1
# au = gamma * u**5 * (u_x**2 + u_y**2) #shallow ice approximation
au = ((u_x**2 + u_y**2)**0.5)**(2.0)
# au = u**3
# au = u*u
# au = -u*u

u1 = au * u_x
u2 = au * u_y

f =  u_t - (u1.diff(x) + u2.diff(y))
f_simplified = sp.simplify(f)

print("aH = ", au)
# print("aH*H_x = ", u1)
# print("aH*H_y = ", u2)
print("Hex.diff(x) = ", u_x)
print("Hex.diff(y) = ", u_y)
print("f(x, u) = ", f_simplified)
